# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import random
import timeit
from citipy import citipy
import requests

# Import the time library and the datetime module from the datetime library 
import time

# %%
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=427464c42ce0fdadfae10c6b37ec53d7

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | ahipara
# Processing Record 2 of Set 1 | qui nhon
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | daru
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 1 | sao francisco de assis
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | neiafu
# Processing Record 10 of Set 1 | kaeo
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | changde
# Processing Record 13 of Set 1 | port blair
# Processing Record 14 of Set 1 | devils lake
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | chambersburg
# Processing Record 20 of Set 1 | saint-joseph
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | nabire
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | margate
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | muros
# Processing Record 30 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | quatre cocos
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | teneguiban
# City not found. Skipping...
# Processing Record 37 of Set 1 | hit
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | nelson bay
# Processing Record 40 of Set 1 | mosquera
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | nome
# Processing Record 43 of Set 1 | fortuna
# Processing Record 44 of Set 1 | antofagasta
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | umm bab
# Processing Record 47 of Set 1 | jamestown
# Processing Record 48 of Set 1 | itarema
# Processing Record 49 of Set 1 | oussouye
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | egvekinot
# Processing Record 5 of Set 2 | cradock
# Processing Record 6 of Set 2 | hay river
# Processing Record 7 of Set 2 | sumbawanga
# Processing Record 8 of Set 2 | port keats
# Processing Record 9 of Set 2 | tuktoyaktuk
# Processing Record 10 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 11 of Set 2 | grindavik
# Processing Record 12 of Set 2 | great bend
# Processing Record 13 of Set 2 | vila franca do campo
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | waingapu
# Processing Record 16 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 2 | parkes
# Processing Record 18 of Set 2 | arauca
# Processing Record 19 of Set 2 | abu samrah
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | yantal
# Processing Record 22 of Set 2 | stockholm
# Processing Record 23 of Set 2 | doctor arroyo
# Processing Record 24 of Set 2 | acoyapa
# Processing Record 25 of Set 2 | sao joao da barra
# Processing Record 26 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 2 | prince albert
# Processing Record 28 of Set 2 | courtenay
# Processing Record 29 of Set 2 | bredasdorp
# Processing Record 30 of Set 2 | tuatapere
# Processing Record 31 of Set 2 | atuona
# Processing Record 32 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | yumen
# Processing Record 35 of Set 2 | klaksvik
# Processing Record 36 of Set 2 | shingu
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | noumea
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 2 | braganca
# Processing Record 42 of Set 2 | deer lake
# Processing Record 43 of Set 2 | chokurdakh
# Processing Record 44 of Set 2 | sete
# Processing Record 45 of Set 2 | vaini
# Processing Record 46 of Set 2 | san cristobal
# Processing Record 47 of Set 2 | narsaq
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | aloleng
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | lubaczow
# Processing Record 2 of Set 3 | behbahan
# Processing Record 3 of Set 3 | tiksi
# Processing Record 4 of Set 3 | ostrovskoye
# Processing Record 5 of Set 3 | vanimo
# Processing Record 6 of Set 3 | bandar-e anzali
# Processing Record 7 of Set 3 | sao joao de pirabas
# Processing Record 8 of Set 3 | raigarh
# Processing Record 9 of Set 3 | marsh harbour
# Processing Record 10 of Set 3 | torbay
# Processing Record 11 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 3 | raudeberg
# Processing Record 13 of Set 3 | touros
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | avera
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | isabela
# Processing Record 19 of Set 3 | necochea
# Processing Record 20 of Set 3 | chililabombwe
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | maragogi
# Processing Record 23 of Set 3 | tigil
# Processing Record 24 of Set 3 | aklavik
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | te anau
# Processing Record 27 of Set 3 | mahibadhoo
# Processing Record 28 of Set 3 | dingle
# Processing Record 29 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 3 | guerrero negro
# Processing Record 31 of Set 3 | comodoro rivadavia
# Processing Record 32 of Set 3 | blitar
# Processing Record 33 of Set 3 | avarua
# Processing Record 34 of Set 3 | puerto escondido
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | castro
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | hecun
# Processing Record 39 of Set 3 | the pas
# Processing Record 40 of Set 3 | dolores
# Processing Record 41 of Set 3 | tiarei
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | ajdabiya
# Processing Record 44 of Set 3 | vung tau
# Processing Record 45 of Set 3 | calvia
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 3 | kapaa
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | bichura
# Processing Record 1 of Set 4 | olinda
# Processing Record 2 of Set 4 | saldanha
# Processing Record 3 of Set 4 | puerto el triunfo
# Processing Record 4 of Set 4 | qaanaaq
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | yellowknife
# Processing Record 7 of Set 4 | grand gaube
# Processing Record 8 of Set 4 | namwala
# Processing Record 9 of Set 4 | grand-santi
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | kolyvan
# Processing Record 13 of Set 4 | puerto ayora
# Processing Record 14 of Set 4 | marsa matruh
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | isla vista
# Processing Record 19 of Set 4 | khandyga
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 4 | kahului
# Processing Record 23 of Set 4 | fort nelson
# Processing Record 24 of Set 4 | maldonado
# Processing Record 25 of Set 4 | wakkanai
# Processing Record 26 of Set 4 | dikson
# Processing Record 27 of Set 4 | jalu
# Processing Record 28 of Set 4 | bon accord
# Processing Record 29 of Set 4 | bendigo
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | leshukonskoye
# Processing Record 32 of Set 4 | bartica
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | thunder bay
# Processing Record 35 of Set 4 | havre-saint-pierre
# Processing Record 36 of Set 4 | pitimbu
# Processing Record 37 of Set 4 | mar del plata
# Processing Record 38 of Set 4 | teguldet
# Processing Record 39 of Set 4 | villanueva de la serena
# Processing Record 40 of Set 4 | banepa
# Processing Record 41 of Set 4 | lima
# Processing Record 42 of Set 4 | brownwood
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | hanstholm
# Processing Record 45 of Set 4 | mahebourg
# Processing Record 46 of Set 4 | hilo
# Processing Record 47 of Set 4 | nsoko
# Processing Record 48 of Set 4 | upernavik
# Processing Record 49 of Set 4 | albanel
# Processing Record 50 of Set 4 | alofi
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | pangai
# Processing Record 3 of Set 5 | kaseda
# Processing Record 4 of Set 5 | adrar
# Processing Record 5 of Set 5 | masuda
# Processing Record 6 of Set 5 | kruisfontein
# Processing Record 7 of Set 5 | vao
# Processing Record 8 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | bengkulu
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | pacasmayo
# Processing Record 13 of Set 5 | asau
# Processing Record 14 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 15 of Set 5 | iqaluit
# Processing Record 16 of Set 5 | nueve de julio
# Processing Record 17 of Set 5 | falmouth
# Processing Record 18 of Set 5 | cabra
# Processing Record 19 of Set 5 | alvand
# Processing Record 20 of Set 5 | puri
# Processing Record 21 of Set 5 | canguaretama
# Processing Record 22 of Set 5 | bonthe
# Processing Record 23 of Set 5 | bowen
# Processing Record 24 of Set 5 | calama
# Processing Record 25 of Set 5 | lae
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | christchurch
# Processing Record 28 of Set 5 | kieta
# Processing Record 29 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 5 | pakxan
# Processing Record 31 of Set 5 | port shepstone
# Processing Record 32 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | homer
# Processing Record 35 of Set 5 | ugento
# Processing Record 36 of Set 5 | beloha
# Processing Record 37 of Set 5 | poplar bluff
# Processing Record 38 of Set 5 | synya
# Processing Record 39 of Set 5 | fare
# Processing Record 40 of Set 5 | miyako
# Processing Record 41 of Set 5 | juneau
# Processing Record 42 of Set 5 | meadow lake
# Processing Record 43 of Set 5 | rocky mountain house
# Processing Record 44 of Set 5 | araouane
# Processing Record 45 of Set 5 | catania
# Processing Record 46 of Set 5 | salalah
# Processing Record 47 of Set 5 | hobyo
# Processing Record 48 of Set 5 | poya
# Processing Record 49 of Set 5 | leh
# Processing Record 50 of Set 5 | hohhot
# Processing Record 1 of Set 6 | kolkwitz
# Processing Record 2 of Set 6 | port hedland
# Processing Record 3 of Set 6 | abdanan
# Processing Record 4 of Set 6 | pangnirtung
# Processing Record 5 of Set 6 | myanaung
# Processing Record 6 of Set 6 | prince rupert
# Processing Record 7 of Set 6 | raga
# Processing Record 8 of Set 6 | katsuura
# Processing Record 9 of Set 6 | mazagao
# Processing Record 10 of Set 6 | longonjo
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | luoyang
# Processing Record 13 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 6 | qandala
# Processing Record 15 of Set 6 | beaumont
# Processing Record 16 of Set 6 | garowe
# Processing Record 17 of Set 6 | robertsport
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | bad wildbad
# Processing Record 20 of Set 6 | bemidji
# Processing Record 21 of Set 6 | berlevag
# Processing Record 22 of Set 6 | yerbogachen
# Processing Record 23 of Set 6 | rio grande
# Processing Record 24 of Set 6 | bafra
# Processing Record 25 of Set 6 | yulara
# Processing Record 26 of Set 6 | diu
# Processing Record 27 of Set 6 | urumqi
# Processing Record 28 of Set 6 | srednekolymsk
# Processing Record 29 of Set 6 | new norfolk
# Processing Record 30 of Set 6 | chhindwara
# Processing Record 31 of Set 6 | harrison
# Processing Record 32 of Set 6 | ancud
# Processing Record 33 of Set 6 | el jicaro
# Processing Record 34 of Set 6 | muravlenko
# Processing Record 35 of Set 6 | keflavik
# Processing Record 36 of Set 6 | ratnagiri
# Processing Record 37 of Set 6 | ribeira grande
# Processing Record 38 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 6 | edd
# Processing Record 42 of Set 6 | harnosand
# Processing Record 43 of Set 6 | lokoja
# Processing Record 44 of Set 6 | auki
# Processing Record 45 of Set 6 | coihaique
# Processing Record 46 of Set 6 | havre
# Processing Record 47 of Set 6 | soyo
# Processing Record 48 of Set 6 | ilheus
# Processing Record 49 of Set 6 | hualmay
# Processing Record 50 of Set 6 | saint-augustin
# Processing Record 1 of Set 7 | airai
# Processing Record 2 of Set 7 | westport
# Processing Record 3 of Set 7 | yarkovo
# Processing Record 4 of Set 7 | oktyabrskoye
# Processing Record 5 of Set 7 | cherskiy
# Processing Record 6 of Set 7 | tagusao
# Processing Record 7 of Set 7 | bubaque
# Processing Record 8 of Set 7 | bantou
# Processing Record 9 of Set 7 | iquique
# Processing Record 10 of Set 7 | tokur
# Processing Record 11 of Set 7 | troitsk
# Processing Record 12 of Set 7 | dukat
# Processing Record 13 of Set 7 | caravelas
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | bilma
# Processing Record 16 of Set 7 | vila velha
# Processing Record 17 of Set 7 | lasa
# Processing Record 18 of Set 7 | sioux lookout
# Processing Record 19 of Set 7 | fukue
# Processing Record 20 of Set 7 | durban
# Processing Record 21 of Set 7 | talnakh
# Processing Record 22 of Set 7 | havoysund
# Processing Record 23 of Set 7 | padang
# Processing Record 24 of Set 7 | lucea
# Processing Record 25 of Set 7 | ust-maya
# Processing Record 26 of Set 7 | yefimovskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | mao
# Processing Record 28 of Set 7 | redlands
# Processing Record 29 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 30 of Set 7 | burns lake
# Processing Record 31 of Set 7 | awbari
# Processing Record 32 of Set 7 | karacabey
# Processing Record 33 of Set 7 | saint anthony
# Processing Record 34 of Set 7 | phon thong
# Processing Record 35 of Set 7 | mackenzie
# Processing Record 36 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 37 of Set 7 | guilin
# Processing Record 38 of Set 7 | bonfim
# Processing Record 39 of Set 7 | tygda
# Processing Record 40 of Set 7 | kurayoshi
# Processing Record 41 of Set 7 | pacific grove
# Processing Record 42 of Set 7 | gao
# Processing Record 43 of Set 7 | ndele
# Processing Record 44 of Set 7 | kouango
# Processing Record 45 of Set 7 | kikwit
# Processing Record 46 of Set 7 | malmesbury
# Processing Record 47 of Set 7 | zhigansk
# Processing Record 48 of Set 7 | terrasini
# Processing Record 49 of Set 7 | camacha
# Processing Record 50 of Set 7 | magaria
# Processing Record 1 of Set 8 | port macquarie
# Processing Record 2 of Set 8 | saravan
# Processing Record 3 of Set 8 | chlorakas
# Processing Record 4 of Set 8 | victoria point
# Processing Record 5 of Set 8 | ulladulla
# Processing Record 6 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 7 of Set 8 | tarko-sale
# Processing Record 8 of Set 8 | troitskoye
# Processing Record 9 of Set 8 | rosarito
# Processing Record 10 of Set 8 | lazaro cardenas
# Processing Record 11 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 8 | ascension
# Processing Record 13 of Set 8 | aitape
# Processing Record 14 of Set 8 | salinopolis
# Processing Record 15 of Set 8 | shu
# Processing Record 16 of Set 8 | petropavl
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | bontang
# Processing Record 20 of Set 8 | paciran
# Processing Record 21 of Set 8 | cairns
# Processing Record 22 of Set 8 | vysokogornyy
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | pundaguitan
# Processing Record 25 of Set 8 | yamada
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | chiria
# Processing Record 28 of Set 8 | tatawin
# Processing Record 29 of Set 8 | shimoda
# Processing Record 30 of Set 8 | marystown
# Processing Record 31 of Set 8 | clovis
# Processing Record 32 of Set 8 | kavaratti
# Processing Record 33 of Set 8 | upington
# Processing Record 34 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 35 of Set 8 | lincoln
# Processing Record 36 of Set 8 | loei
# Processing Record 37 of Set 8 | kerema
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | sao felix do xingu
# Processing Record 40 of Set 8 | narasimharajapura
# Processing Record 41 of Set 8 | guiren
# Processing Record 42 of Set 8 | naze
# Processing Record 43 of Set 8 | de-kastri
# Processing Record 44 of Set 8 | okitipupa
# Processing Record 45 of Set 8 | sabha
# Processing Record 46 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 8 | iquitos
# Processing Record 48 of Set 8 | vila
# Processing Record 49 of Set 8 | xai-xai
# Processing Record 50 of Set 8 | geraldton
# Processing Record 1 of Set 9 | gazojak
# Processing Record 2 of Set 9 | asyut
# Processing Record 3 of Set 9 | nioro
# Processing Record 4 of Set 9 | kavieng
# Processing Record 5 of Set 9 | waycross
# Processing Record 6 of Set 9 | oistins
# Processing Record 7 of Set 9 | luanda
# Processing Record 8 of Set 9 | negombo
# Processing Record 9 of Set 9 | abu zabad
# Processing Record 10 of Set 9 | yar-sale
# Processing Record 11 of Set 9 | quelimane
# Processing Record 12 of Set 9 | maningrida
# Processing Record 13 of Set 9 | poykovskiy
# Processing Record 14 of Set 9 | omaruru
# Processing Record 15 of Set 9 | tarakan
# Processing Record 16 of Set 9 | san salvador
# Processing Record 17 of Set 9 | seymchan
# Processing Record 18 of Set 9 | winslow
# Processing Record 19 of Set 9 | sheregesh
# Processing Record 20 of Set 9 | osypenko
# Processing Record 21 of Set 9 | bilibino
# Processing Record 22 of Set 9 | nikki
# Processing Record 23 of Set 9 | baglung
# Processing Record 24 of Set 9 | kokstad
# Processing Record 25 of Set 9 | sasaram
# Processing Record 26 of Set 9 | umm kaddadah
# Processing Record 27 of Set 9 | mareeba
# Processing Record 28 of Set 9 | obihiro
# Processing Record 29 of Set 9 | guaruja
# Processing Record 30 of Set 9 | rocha
# Processing Record 31 of Set 9 | san juan
# Processing Record 32 of Set 9 | farmington
# Processing Record 33 of Set 9 | hervey bay
# Processing Record 34 of Set 9 | san jose
# Processing Record 35 of Set 9 | gondanglegi
# Processing Record 36 of Set 9 | alberton
# Processing Record 37 of Set 9 | ho chi minh city
# Processing Record 38 of Set 9 | burica
# City not found. Skipping...
# Processing Record 39 of Set 9 | saint george
# Processing Record 40 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 9 | xuddur
# Processing Record 42 of Set 9 | devonport
# Processing Record 43 of Set 9 | ocos
# Processing Record 44 of Set 9 | nemuro
# Processing Record 45 of Set 9 | omboue
# Processing Record 46 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 9 | sur
# Processing Record 48 of Set 9 | nikel
# Processing Record 49 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 9 | balaipungut
# Processing Record 1 of Set 10 | lukiv
# Processing Record 2 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 10 | rolante
# Processing Record 4 of Set 10 | buchanan
# Processing Record 5 of Set 10 | chikoy
# City not found. Skipping...
# Processing Record 6 of Set 10 | oranjemund
# Processing Record 7 of Set 10 | numan
# Processing Record 8 of Set 10 | lagoa
# Processing Record 9 of Set 10 | mount gambier
# Processing Record 10 of Set 10 | katobu
# Processing Record 11 of Set 10 | kabanjahe
# Processing Record 12 of Set 10 | atambua
# Processing Record 13 of Set 10 | elko
# Processing Record 14 of Set 10 | abu kamal
# Processing Record 15 of Set 10 | lubango
# Processing Record 16 of Set 10 | buraydah
# Processing Record 17 of Set 10 | sosnogorsk
# Processing Record 18 of Set 10 | letlhakane
# Processing Record 19 of Set 10 | mandalgovi
# Processing Record 20 of Set 10 | monterey
# Processing Record 21 of Set 10 | tocopilla
# Processing Record 22 of Set 10 | boende
# Processing Record 23 of Set 10 | basyanovskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | houma
# Processing Record 25 of Set 10 | pattan
# Processing Record 26 of Set 10 | cascais
# Processing Record 27 of Set 10 | kalmunai
# Processing Record 28 of Set 10 | tawzar
# City not found. Skipping...
# Processing Record 29 of Set 10 | zhanaozen
# Processing Record 30 of Set 10 | swan hill
# Processing Record 31 of Set 10 | odweyne
# Processing Record 32 of Set 10 | cidreira
# Processing Record 33 of Set 10 | leningradskiy
# Processing Record 34 of Set 10 | bara
# Processing Record 35 of Set 10 | channel-port aux basques
# Processing Record 36 of Set 10 | sobolevo
# Processing Record 37 of Set 10 | wanning
# Processing Record 38 of Set 10 | vanavara
# Processing Record 39 of Set 10 | binzhou
# Processing Record 40 of Set 10 | redmond
# Processing Record 41 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 10 | valparaiso
# Processing Record 43 of Set 10 | batagay
# Processing Record 44 of Set 10 | aykhal
# Processing Record 45 of Set 10 | soavinandriana
# Processing Record 46 of Set 10 | olafsvik
# Processing Record 47 of Set 10 | awjilah
# Processing Record 48 of Set 10 | nelspruit
# Processing Record 49 of Set 10 | governador valadares
# Processing Record 50 of Set 10 | brigantine
# Processing Record 1 of Set 11 | manggar
# Processing Record 2 of Set 11 | faya
# Processing Record 3 of Set 11 | lieksa
# Processing Record 4 of Set 11 | buala
# Processing Record 5 of Set 11 | flin flon
# Processing Record 6 of Set 11 | nusaybin
# Processing Record 7 of Set 11 | krasnoselkup
# Processing Record 8 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 9 of Set 11 | chapais
# Processing Record 10 of Set 11 | hauge
# Processing Record 11 of Set 11 | mayo
# Processing Record 12 of Set 11 | usinsk
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 11 | mount isa
# Processing Record 16 of Set 11 | kirakira
# Processing Record 17 of Set 11 | porto novo
# Processing Record 18 of Set 11 | kaniama
# Processing Record 19 of Set 11 | fort smith
# Processing Record 20 of Set 11 | astoria
# Processing Record 21 of Set 11 | pljevlja
# Processing Record 22 of Set 11 | iranshahr
# Processing Record 23 of Set 11 | trebinje
# Processing Record 24 of Set 11 | ban nahin
# Processing Record 25 of Set 11 | choix
# Processing Record 26 of Set 11 | pevek
# Processing Record 27 of Set 11 | billings
# Processing Record 28 of Set 11 | dudinka
# Processing Record 29 of Set 11 | wuzhou
# Processing Record 30 of Set 11 | padilla
# Processing Record 31 of Set 11 | inverness
# Processing Record 32 of Set 11 | kashi
# Processing Record 33 of Set 11 | kulhudhuffushi
# Processing Record 34 of Set 11 | nyurba
# Processing Record 35 of Set 11 | ligayan
# Processing Record 36 of Set 11 | hasaki
# Processing Record 37 of Set 11 | along
# Processing Record 38 of Set 11 | sept-iles
# Processing Record 39 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | lavrentiya
# Processing Record 42 of Set 11 | ishigaki
# Processing Record 43 of Set 11 | norman wells
# Processing Record 44 of Set 11 | aksu
# Processing Record 45 of Set 11 | taltal
# Processing Record 46 of Set 11 | beringovskiy
# Processing Record 47 of Set 11 | palmer
# Processing Record 48 of Set 11 | namatanai
# Processing Record 49 of Set 11 | bambous virieux
# Processing Record 50 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 12 | mundra
# Processing Record 2 of Set 12 | pulandian
# Processing Record 3 of Set 12 | san miguel
# Processing Record 4 of Set 12 | peniche
# Processing Record 5 of Set 12 | zanatepec
# City not found. Skipping...
# Processing Record 6 of Set 12 | novosergiyevka
# Processing Record 7 of Set 12 | saint-francois
# Processing Record 8 of Set 12 | pittsburg
# Processing Record 9 of Set 12 | antsohihy
# Processing Record 10 of Set 12 | san quintin
# Processing Record 11 of Set 12 | atemar
# Processing Record 12 of Set 12 | sidi ali
# Processing Record 13 of Set 12 | sao geraldo do araguaia
# Processing Record 14 of Set 12 | ambulu
# Processing Record 15 of Set 12 | camana
# Processing Record 16 of Set 12 | ucluelet
# Processing Record 17 of Set 12 | horni plana
# Processing Record 18 of Set 12 | diamantino
# Processing Record 19 of Set 12 | goderich
# Processing Record 20 of Set 12 | northam
# Processing Record 21 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 22 of Set 12 | seoul
# Processing Record 23 of Set 12 | eugene
# Processing Record 24 of Set 12 | amuntai
# Processing Record 25 of Set 12 | galle
# Processing Record 26 of Set 12 | nuevo laredo
# Processing Record 27 of Set 12 | moroni
# Processing Record 28 of Set 12 | belmonte
# Processing Record 29 of Set 12 | sergiyevsk
# Processing Record 30 of Set 12 | show low
# Processing Record 31 of Set 12 | ilhabela
# Processing Record 32 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 12 | husavik
# Processing Record 34 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 35 of Set 12 | davila
# Processing Record 36 of Set 12 | mehamn
# Processing Record 37 of Set 12 | piney green
# Processing Record 38 of Set 12 | merauke
# Processing Record 39 of Set 12 | brae
# Processing Record 40 of Set 12 | los llanos de aridane
# Processing Record 41 of Set 12 | motygino
# Processing Record 42 of Set 12 | maceio
# Processing Record 43 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 44 of Set 12 | mananara
# Processing Record 45 of Set 12 | acari
# Processing Record 46 of Set 12 | gouyave
# Processing Record 47 of Set 12 | tazovskiy
# Processing Record 48 of Set 12 | lorengau
# Processing Record 49 of Set 12 | ko samui
# Processing Record 50 of Set 12 | rolla
# Processing Record 1 of Set 13 | kalanwali
# Processing Record 2 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 3 of Set 13 | hauterive
# Processing Record 4 of Set 13 | saint-georges
# Processing Record 5 of Set 13 | bonga
# Processing Record 6 of Set 13 | north bend
# Processing Record 7 of Set 13 | praia da vitoria
# Processing Record 8 of Set 13 | gizo
# Processing Record 9 of Set 13 | haines junction
# Processing Record 10 of Set 13 | aripuana
# Processing Record 11 of Set 13 | aksarayskiy
# Processing Record 12 of Set 13 | peleduy
# Processing Record 13 of Set 13 | celestun
# Processing Record 14 of Set 13 | ribas do rio pardo
# Processing Record 15 of Set 13 | lufilufi
# Processing Record 16 of Set 13 | baruun-urt
# Processing Record 17 of Set 13 | hailar
# Processing Record 18 of Set 13 | kidal
# Processing Record 19 of Set 13 | stettler
# Processing Record 20 of Set 13 | boueni
# Processing Record 21 of Set 13 | bandarbeyla
# Processing Record 22 of Set 13 | berck
# Processing Record 23 of Set 13 | masuguru
# Processing Record 24 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 13 | kalevala
# Processing Record 26 of Set 13 | jinchang
# Processing Record 27 of Set 13 | rio gallegos
# Processing Record 28 of Set 13 | siverek
# Processing Record 29 of Set 13 | karwar
# Processing Record 30 of Set 13 | afikpo
# Processing Record 31 of Set 13 | chiang klang
# Processing Record 32 of Set 13 | matadi
# Processing Record 33 of Set 13 | dunedin
# Processing Record 34 of Set 13 | dilla
# Processing Record 35 of Set 13 | narrabri
# Processing Record 36 of Set 13 | hastings
# Processing Record 37 of Set 13 | bonoua
# Processing Record 38 of Set 13 | skjervoy
# Processing Record 39 of Set 13 | cooma
# Processing Record 40 of Set 13 | sicamous
# Processing Record 41 of Set 13 | coahuayana
# Processing Record 42 of Set 13 | mendahara
# City not found. Skipping...
# Processing Record 43 of Set 13 | albion
# Processing Record 44 of Set 13 | namtsy
# Processing Record 45 of Set 13 | key west
# Processing Record 46 of Set 13 | sabang
# Processing Record 47 of Set 13 | pahrump
# Processing Record 48 of Set 13 | mokhsogollokh
# Processing Record 49 of Set 13 | luwuk
# Processing Record 50 of Set 13 | cristalina
# Processing Record 1 of Set 14 | tchibanga
# Processing Record 2 of Set 14 | assiniboia
# Processing Record 3 of Set 14 | ulaanbaatar
# Processing Record 4 of Set 14 | mujiayingzi
# Processing Record 5 of Set 14 | kristiansund
# Processing Record 6 of Set 14 | sechura
# Processing Record 7 of Set 14 | el alto
# Processing Record 8 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 14 | dasoguz
# Processing Record 10 of Set 14 | thyboron
# Processing Record 11 of Set 14 | verkhoyansk
# Processing Record 12 of Set 14 | novopokrovka
# Processing Record 13 of Set 14 | chabahar
# Processing Record 14 of Set 14 | mandurah
# Processing Record 15 of Set 14 | huarmey
# Processing Record 16 of Set 14 | port hueneme
# Processing Record 17 of Set 14 | tonekabon
# Processing Record 18 of Set 14 | macamic
# Processing Record 19 of Set 14 | san luis
# Processing Record 20 of Set 14 | nurota
# Processing Record 21 of Set 14 | soderhamn
# Processing Record 22 of Set 14 | oum hadjer
# Processing Record 23 of Set 14 | khash
# Processing Record 24 of Set 14 | ardahan
# Processing Record 25 of Set 14 | tanete
# Processing Record 26 of Set 14 | warrnambool
# Processing Record 27 of Set 14 | epsom
# Processing Record 28 of Set 14 | ulaangom
# Processing Record 29 of Set 14 | vostok
# Processing Record 30 of Set 14 | kurumkan
# Processing Record 31 of Set 14 | banikoara
# Processing Record 32 of Set 14 | yook
# Processing Record 33 of Set 14 | corn island
# Processing Record 34 of Set 14 | penzance
# Processing Record 35 of Set 14 | aksarka
# Processing Record 36 of Set 14 | tucuman
# Processing Record 37 of Set 14 | kamenka
# Processing Record 38 of Set 14 | tessalit
# Processing Record 39 of Set 14 | ntungamo
# Processing Record 40 of Set 14 | lar gerd
# City not found. Skipping...
# Processing Record 41 of Set 14 | san patricio
# Processing Record 42 of Set 14 | owando
# Processing Record 43 of Set 14 | khasan
# Processing Record 44 of Set 14 | kharagpur
# Processing Record 45 of Set 14 | chirongui
# Processing Record 46 of Set 14 | rawson
# Processing Record 47 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 48 of Set 14 | columbus
# Processing Record 49 of Set 14 | almenara
# Processing Record 50 of Set 14 | vestmannaeyjar
# Processing Record 1 of Set 15 | road town
# Processing Record 2 of Set 15 | san pedro de uraba
# Processing Record 3 of Set 15 | bayan
# Processing Record 4 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 15 | myaundzha
# Processing Record 6 of Set 15 | uch
# Processing Record 7 of Set 15 | shizukuishi
# Processing Record 8 of Set 15 | guanare
# Processing Record 9 of Set 15 | rajkot
# Processing Record 10 of Set 15 | santa maria
# Processing Record 11 of Set 15 | nyrob
# Processing Record 12 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 13 of Set 15 | shitanjing
# Processing Record 14 of Set 15 | timiryazevskoye
# Processing Record 15 of Set 15 | champerico
# Processing Record 16 of Set 15 | nouadhibou
# Processing Record 17 of Set 15 | abong mbang
# Processing Record 18 of Set 15 | plyussa
# Processing Record 19 of Set 15 | charters towers
# Processing Record 20 of Set 15 | arlit
# Processing Record 21 of Set 15 | jian
# Processing Record 22 of Set 15 | cap malheureux
# Processing Record 23 of Set 15 | virginia beach
# Processing Record 24 of Set 15 | bambanglipuro
# Processing Record 25 of Set 15 | rauma
# Processing Record 26 of Set 15 | hami
# Processing Record 27 of Set 15 | carbonia
# Processing Record 28 of Set 15 | uusikaupunki
# Processing Record 29 of Set 15 | havelock
# Processing Record 30 of Set 15 | chandler
# Processing Record 31 of Set 15 | gat
# Processing Record 32 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 33 of Set 15 | geilo
# Processing Record 34 of Set 15 | russell
# Processing Record 35 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 15 | arti
# Processing Record 37 of Set 15 | changzhou
# Processing Record 38 of Set 15 | cartagena
# Processing Record 39 of Set 15 | sao jose da coroa grande
# Processing Record 40 of Set 15 | lancaster
# Processing Record 41 of Set 15 | stornoway
# Processing Record 42 of Set 15 | rubtsovsk
# Processing Record 43 of Set 15 | porbandar
# Processing Record 44 of Set 15 | ponta delgada
# Processing Record 45 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 15 | qaqortoq
# Processing Record 47 of Set 15 | kalengwa
# Processing Record 48 of Set 15 | sao sebastiao
# Processing Record 49 of Set 15 | laminusa
# Processing Record 50 of Set 15 | bitung
# Processing Record 1 of Set 16 | port said
# Processing Record 2 of Set 16 | puerto madero
# Processing Record 3 of Set 16 | viedma
# Processing Record 4 of Set 16 | rudnogorsk
# Processing Record 5 of Set 16 | xining
# Processing Record 6 of Set 16 | rabo de peixe
# Processing Record 7 of Set 16 | taoudenni
# Processing Record 8 of Set 16 | balabac
# Processing Record 9 of Set 16 | roxas
# Processing Record 10 of Set 16 | waipawa
# Processing Record 11 of Set 16 | koroni
# Processing Record 12 of Set 16 | oromocto
# Processing Record 13 of Set 16 | nantucket
# Processing Record 14 of Set 16 | aquidauana
# Processing Record 15 of Set 16 | kargapolye
# City not found. Skipping...
# Processing Record 16 of Set 16 | alice springs
# Processing Record 17 of Set 16 | borzya
# Processing Record 18 of Set 16 | menongue
# Processing Record 19 of Set 16 | benguela
# Processing Record 20 of Set 16 | jabinyanah
# Processing Record 21 of Set 16 | hornepayne
# Processing Record 22 of Set 16 | natal
# Processing Record 23 of Set 16 | maniitsoq
# Processing Record 24 of Set 16 | bosaso
# Processing Record 25 of Set 16 | am timan
# Processing Record 26 of Set 16 | pauini
# Processing Record 27 of Set 16 | la rochelle
# Processing Record 28 of Set 16 | blonduos
# City not found. Skipping...
# Processing Record 29 of Set 16 | san ramon
# Processing Record 30 of Set 16 | vaitape
# Processing Record 31 of Set 16 | umea
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Ahipara -35.1667  173.1667     62.62        74         100
# 1                Qui Nhon  13.7667  109.2333     86.32        66          99
# 2               Busselton -33.6500  115.3333     57.69        60          95
# 3                    Daru  -9.0763  143.2092     79.38        87          68
# 4                Hermanus -34.4187   19.2345     54.19        80          46
# 5  Sao Francisco De Assis -29.5503  -55.1311     70.84        66          43
# 6                  Kodiak  57.7900 -152.4072     54.91        76         100
# 7                  Neiafu -18.6500 -173.9833     81.28        74          40
# 8                    Kaeo -35.1000  173.7833     65.32        86         100
# 9                  Hobart -42.8794  147.3294     53.46        71          75
#
#    Wind Speed Country Current Description
# 0        4.21      NZ     overcast clouds
# 1        8.08      VN       moderate rain
# 2       13.53      AU     overcast clouds
# 3       15.21      PG       broken clouds
# 4        4.63      ZA    scattered clouds
# 5       16.04      BR    scattered clouds
# 6       11.50      US     overcast clouds
# 7       13.80      TO    scattered clouds
# 8        3.83      NZ     overcast clouds
# 9       10.36      AU       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ahipara      NZ -35.1667  173.1667     62.62        74         100
# 1       Qui Nhon      VN  13.7667  109.2333     86.32        66          99
# 2      Busselton      AU -33.6500  115.3333     57.69        60          95
# 3           Daru      PG  -9.0763  143.2092     79.38        87          68
# 4       Hermanus      ZA -34.4187   19.2345     54.19        80          46
# ..           ...     ...      ...       ...       ...       ...         ...
# 715       Pauini      BR  -7.7136  -66.9764     75.79        71          55
# 716  La Rochelle      FR  46.1667   -1.1500     69.94        68           0
# 717    San Ramon      US  37.7799 -121.9780     76.39        70           0
# 718      Vaitape      PF -16.5167 -151.7500     78.28        72          65
# 719         Umea      SE  63.8284   20.2597     51.91       100          40
#
#      Wind Speed Current Description
# 0          4.21     overcast clouds
# 1          8.08       moderate rain
# 2         13.53     overcast clouds
# 3         15.21       broken clouds
# 4          4.63    scattered clouds
# ..          ...                 ...
# 715        1.72       broken clouds
# 716       11.50           clear sky
# 717       11.50           clear sky
# 718       18.68       broken clouds
# 719        4.61    scattered clouds
#
# [720 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
